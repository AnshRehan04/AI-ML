# %%
import pandas as pd

# %%
df=pd.read_csv("apple_quality.csv")
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df=pd.read_csv("apple_quality.csv")
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.describe()
# Out:
#             A_id       Size     Weight  Sweetness  Crunchiness  Juiciness  \
# count  34.000000  34.000000  34.000000  34.000000    34.000000  34.000000
# mean   16.500000  -0.638347  -1.203618  -0.344124     0.967611   0.899746
# std     9.958246   1.798912   1.592557   2.236297     1.808872   2.398431
# min     0.000000  -3.970049  -4.714750  -4.092223    -1.677798  -4.207544
# 25%     8.250000  -2.079903  -2.268792  -1.776102    -0.328263  -0.410073
# 50%    16.500000  -0.592311  -1.313059  -1.074600     0.729971   1.239522
# 75%    24.750000   0.494844  -0.432424   0.970073     1.678780   2.857996
# max    33.000000   2.839581   1.724396   5.346330     7.619852   5.148739
#
#         Ripeness    Acidity
# count  34.000000  34.000000
# mean    0.163407  -0.055399
# std     2.365531   2.402380
# min    -4.630174  -4.871905
# 25%    -1.317792  -1.924617
# 50%     0.351585   0.005197
# 75%     1.154351   1.720447
# max     6.346445   5.560109

# %%
df.head(3)
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad

# %%
# df.loc[40:60]
df.iloc[40:60]
# Out:
#     A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 40  40.0  1.196545 -1.448104  -0.921517     2.005491   0.404741 -0.700779
# 41  41.0 -0.354190 -2.024043   1.366985     3.233616   0.992669  1.525609
# 42  42.0 -1.538607 -2.747844   1.844950     0.491249  -0.425816  1.259768
# 43  43.0  0.807854  0.752707   0.179226     1.451582  -1.611859 -2.776275
# 44  44.0  3.930361  2.754406  -2.667950     1.428248   0.092761  1.095794
# 45  45.0  0.033471 -0.044161  -0.481202     4.937210  -0.609873 -3.231504
# 46  46.0 -0.487367 -0.768805  -0.779232     2.025257   1.477927  0.267788
# 47  47.0 -1.387990  2.738511  -2.349217     0.953438   1.860716  2.317310
# 48  48.0 -3.328571  0.652577  -1.424403     0.727385   1.576921  2.577804
# 49  49.0 -1.107060  2.261198  -2.635197     0.882265  -0.023995  2.218099
# 50  50.0 -2.938617  0.524455   0.802257    -1.475931  -0.336349  1.430648
# 51  51.0 -0.411308 -1.758595  -2.213865    -0.149535   1.576184  0.929197
# ...

# %%
df[4:6]
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5   5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
#
#         Acidity Quality
# 4   0.501984036    good
# 5  -2.981523169     bad

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4001, step=1)

# %%
df.value_counts()
# Out:
# A_id    Size       Weight     Sweetness  Crunchiness  Juiciness  Ripeness   Acidity       Quality
# 0.0     -3.970049  -2.512336   5.346330  -1.012009     1.844900   0.329840  -0.491590483  good       1
# 2671.0  -3.844134  -2.729138  -0.812468   1.390671     1.839132   5.411911  1.006877454   bad        1
# 2658.0  -4.411655   2.702494  -0.708549  -2.162584    -0.664962   0.751173  -0.132407603  good       1
# 2659.0  -1.480046  -0.326744  -1.453041   0.898155     1.372992   0.762387  1.223084441   bad        1
# 2660.0   0.749942  -2.590200  -1.227472   0.322952    -1.046933  -0.030211  2.190636353   bad        1
#                                                                                                     ..
# 1338.0  -2.385353  -2.367245  -1.600530   1.851129     1.759377   1.508037  -3.873112715  bad        1
# 1339.0   0.612499  -3.353272  -0.636006   1.037675     1.838079  -1.629855  -0.08899782   good       1
# ...

# %%
df.iloc[4]
# Out:
# A_id                   4.0
# Size              1.364217
# Weight           -1.296612
# Sweetness        -0.384658
# Crunchiness      -0.553006
# Juiciness         3.030874
# Ripeness         -1.303849
# Acidity        0.501984036
# Quality               good
# Name: 4, dtype: object

# %%
df.Size
# Out:
# 0      -3.970049
# 1      -1.195217
# 2      -0.292024
# 3      -0.657196
# 4       1.364217
#           ...
# 3996   -0.293118
# 3997   -2.634515
# 3998   -4.008004
# 3999    0.278540
# 4000         NaN
# Name: Size, Length: 4001, dtype: float64

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df["A_id"][3]
# Out:
# 3.0

# %%
df.iloc[0]
# Out:
# A_id                    0.0
# Size              -3.970049
# Weight            -2.512336
# Sweetness           5.34633
# Crunchiness       -1.012009
# Juiciness            1.8449
# Ripeness            0.32984
# Acidity        -0.491590483
# Quality                good
# Name: 0, dtype: object

# %%
df.loc[4,"Quality"]
# Out:
# 'good'

# %%
df.loc[:3,["A_id","Quality"]]
# Out:
#    A_id Quality
# 0   0.0    good
# 1   1.0    good
# 2   2.0     bad
# 3   3.0    good

# %%
df.set_index("Size")
# Out:
#              A_id    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# Size
# -3.970049     0.0 -2.512336   5.346330    -1.012009   1.844900  0.329840
# -1.195217     1.0 -2.839257   3.664059     1.588232   0.853286  0.867530
# -0.292024     2.0 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# -0.657196     3.0 -2.271627   1.324874    -0.097875   3.637970 -3.413761
#  1.364217     4.0 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...           ...       ...        ...          ...        ...       ...
# -0.293118  3996.0  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# -2.634515  3997.0 -2.138247  -2.440461     0.657223   2.199709  4.763859
# -4.008004  3998.0 -1.779337   2.366397    -0.200329   2.161435  0.214488
#  0.278540  3999.0 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#  NaN          NaN       NaN        NaN          NaN        NaN       NaN
#
#                                      Acidity Quality
# Size
# ...

# %%
df.Quality=="good"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 3996     True
# 3997    False
# 3998     True
# 3999     True
# 4000    False
# Name: Quality, Length: 4001, dtype: bool

# %%
df.loc[df.Quality=="good"]
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 6        6.0  1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
# ...      ...       ...       ...        ...          ...        ...       ...
# 3992  3992.0  1.764253 -2.079695  -0.083383    -0.086724  -1.703385  3.840101
# 3994  3994.0  1.482508 -2.581181  -0.306888     1.527877   1.056361  2.560829
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
# df.loc[df.A_id>10.0]
df.loc[df.Quality=="bad"]
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 5        5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 8        8.0 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 9        9.0 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
# 10      10.0 -2.699336 -1.329507  -1.418507    -0.625546   2.371074  3.403165
# ...      ...       ...       ...        ...          ...        ...       ...
# 3989  3989.0 -2.282625 -0.225517  -1.698524     0.936855  -1.385481  3.249894
# 3990  3990.0 -1.396794 -0.599596  -1.931104     1.815668   1.670732  1.614027
# 3993  3993.0  1.520142 -0.352623  -3.206467     1.341719   0.675568  0.107093
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
#
#            Acidity Quality
# ...

# %%
df.loc[df.Quality.isin(["good","bad"])]
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
# Assigning

# %%
df["Quality"]="poor"
# df["Quality"]
df.Quality
# Out:
# 0       poor
# 1       poor
# 2       poor
# 3       poor
# 4       poor
#         ...
# 3996    poor
# 3997    poor
# 3998    poor
# 3999    poor
# 4000    poor
# Name: Quality, Length: 4001, dtype: object

# %%
df.rename(columns={"A_id":"B_id"})  #rename is used to rename the columns
# Out:
#         B_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.A_id.describe()
# Out:
# count    4000.000000
# mean     1999.500000
# std      1154.844867
# min         0.000000
# 25%       999.750000
# 50%      1999.500000
# 75%      2999.250000
# max      3999.000000
# Name: A_id, dtype: float64

# %%
df.A_id.mean()
# Out:
# 1999.5

# %%
df.A_id.max()
# Out:
# 3999.0

# %%
df.A_id.sum()
# Out:
# 7998000.0

# %%
df.A_id.min()
# Out:
# 0.0

# %%
df.Quality.unique()
# Out:
# array(['poor'], dtype=object)

# %%
df.Quality.value_counts()
# Out:
# Quality
# poor    4001
# Name: count, dtype: int64

# %%
df.A_id.value_counts()
# Out:
# A_id
# 0.0       1
# 2671.0    1
# 2658.0    1
# 2659.0    1
# 2660.0    1
#          ..
# 1338.0    1
# 1339.0    1
# 1340.0    1
# 1341.0    1
# 3999.0    1
# Name: count, Length: 4000, dtype: int64
